# %%
print("Hello AI")
# Out:
# Hello AI

# %%
# 试试向量运算
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print(f"向量 a: {a}")
print(f"向量 b: {b}")
print(f"点积: {np.dot(a, b)}")
# Out:
# 向量 a: [1 2 3]
# 向量 b: [4 5 6]
# 点积: 32
